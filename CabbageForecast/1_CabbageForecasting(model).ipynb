# %%
# 패키지 임포트 
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

# %% [markdown]
# ## 학습모델을 저장하는 이유
# - 만약 학습 모델을 저장하지 않고 사용자로 부터 배추가격 예측 요청이 발생할때마다 매번 학습을 해서 결과를 돌려준다면 시간이 오래 걸리고 많은 리소스가 소모
# - 오프라인에서 주기적으로 데이터를 이용해 학습진행
# - 그결과를 저장해서 서버에서 실시간 요청에 따라 **이미 저장된 학습모델로 배추가격을 예측하는것이 효율적**

# %%
# 모델 초기화 
model = tf.global_variables_initializer
# 데이터 로드 => 데이터 프레임 형태를 변경해줘야함 
data = read_csv('./data/price data.csv',sep=',')
data
# Out:
#           year  avgTemp  minTemp  maxTemp  rainFall  avgPrice
# 0     20100101     -4.9    -11.0      0.9       0.0      2123
# 1     20100102     -3.1     -5.5      5.5       0.8      2123
# 2     20100103     -2.9     -6.9      1.4       0.0      2123
# 3     20100104     -1.8     -5.1      2.2       5.9      2020
# 4     20100105     -5.2     -8.7     -1.8       0.7      2060
# 5     20100106     -7.3    -11.4     -2.5       0.3      2060
# 6     20100107     -6.7    -11.2     -1.2       0.0      2140
# 7     20100108     -5.6    -11.4      1.4       0.0      2140
# 8     20100109     -3.1     -8.8      1.8       0.1      2140
# 9     20100110     -1.3     -5.0      2.8       0.0      2140
# 10    20100111     -1.5     -5.1      2.1       0.0      2140
# 11    20100112     -5.0     -8.2     -1.7       0.4      2140
# 12    20100113     -8.3    -11.4     -4.6       0.7      2140
# 13    20100114     -6.4    -12.7      0.0       0.1      2140
# 14    20100115     -2.6     -7.9      3.9       0.1      2140
# 15    20100116     -4.1     -9.9      2.9       0.0      2140
# 16    20100117     -3.1     -9.8      4.9       0.0      2140
# 17    20100118     -0.4     -7.1      7.7       0.0      2140
# 18    20100119      3.6     -4.6     11.0       0.3      2140
# 19    20100120      8.0      4.9     11.3      10.8      2175
# 20    20100121      1.3     -3.6      7.9       3.1      2211
# 21    20100122     -3.1     -5.7      0.8       0.0      2211
# 22    20100123     -2.7     -6.6      2.0       0.1      2211
# 23    20100124      0.4     -5.5      5.8       0.0      2211
# 24    20100125      0.8     -4.3      5.4       0.0      2211
# 25    20100126     -2.3     -7.7      4.3       0.0      2178
# 26    20100127      1.3     -5.9      7.4       6.5      2178
# 27    20100128      3.5     -0.7      7.4       0.1      2311
# 28    20100129      0.2     -4.3      5.0       0.0      2344
# 29    20100130      1.9     -3.3      7.5       0.0      2344
# ...        ...      ...      ...      ...       ...       ...
# 2892  20171202      1.3     -4.9      8.1       0.0      2727
# 2893  20171203      4.4     -1.7     11.0       0.5      2727
# 2894  20171204      2.2     -2.6      6.9       0.2      2677
# 2895  20171205     -2.3     -6.0      1.9       0.2      2670
# 2896  20171206      0.6     -5.2      6.7       0.9      2657
# 2897  20171207      2.6     -1.9      7.6       0.9      2653
# 2898  20171208     -1.3     -4.3      2.4       0.2      2688
# 2899  20171209      0.7     -4.5      6.2       0.0      2688
# 2900  20171210      3.5     -1.1      8.9       2.2      2688
# 2901  20171211     -3.0     -6.7      1.7       0.2      2637
# 2902  20171212     -6.0     -9.7     -1.7       0.0      2637
# 2903  20171213     -5.2     -9.6      0.4       0.0      2637
# 2904  20171214     -4.0    -10.5      2.8       0.0      2635
# 2905  20171215     -0.8     -7.2      4.7       0.0      2635
# 2906  20171216     -1.7     -5.6      2.1       0.2      2635
# 2907  20171217     -4.4     -9.0      0.3       0.1      2635
# 2908  20171218     -0.2     -7.3      5.7       0.3      2743
# 2909  20171219     -1.3     -5.9      3.4       0.1      2765
# 2910  20171220     -1.5     -7.8      4.7       0.7      2788
# 2911  20171221     -0.1     -4.8      5.8       0.0      2788
# 2912  20171222      1.7     -4.3      8.5       0.0      2800
# 2913  20171223      3.9     -1.1     11.0       0.0      2800
# 2914  20171224      4.3      1.3      8.1      14.2      2800
# 2915  20171225      0.2     -2.7      3.5       0.0      2800
# 2916  20171226     -0.6     -4.9      4.1       0.1      2823
# 2917  20171227     -3.9     -8.0      0.7       0.0      2865
# 2918  20171228     -1.5     -6.9      3.7       0.0      2884
# 2919  20171229      2.9     -2.1      8.0       0.0      2901
# 2920  20171230      2.9     -1.6      7.1       0.6      2901
# 2921  20171231      2.1     -2.0      5.8       0.4      2901
#
# [2922 rows x 6 columns]

# %%
# array 명령으로 배열을 생성 => 자료형을 명시적으로 적용
xy = np.array(data, dtype = np.float32)

# %%
# 4개의 변인을 입력 받는다 => 평균기온, 최대,최소기온, 강수량 
x_data = xy[:,1:-1]
y_data = xy[:,[-1]]

# %%
#플레이스 홀드로 x,y 값을 정의
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
# 가중치와 바이어스 값을 초기화 
W =tf.Variable(tf.random_normal([4,1]), name="weight")
b = tf.Variable(tf.random_normal([1]),name="bias")
# 선형회귀모델을 그대로 이용
# Out:
# WARNING:tensorflow:From C:\Users\sun41\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#가설을 설정 =>  행열의 곱연산식 
hypothesis = tf.matmul(X,W) + b

# %%
# 비용함수 
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 옵티마이저 => 학습률 0.00005
# 최적화 함수를 설정 
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
# 세션
sess =tf.Session()
# 글로벌 변수 초기화 
sess.run(tf.global_variables_initializer())

# %%
# 학습 진행 
for step in range(100001):
    cost_,hypo_,_ = sess.run([cost, hypothesis,train], feed_dict={X:x_data, Y:y_data})
    if step % 500 == 0:
        print("#",step , "손실비용 : ", cost_)
        print("- 배추가격 : ", hypo_[0])
# Out:
# # 0 손실비용 :  12402186.0
# - 배추가격 :  [-7.408686]
# # 500 손실비용 :  4194289.8
# - 배추가격 :  [-276.81323]
# # 1000 손실비용 :  3787597.0
# - 배추가격 :  [33.26064]
# # 1500 손실비용 :  3469977.5
# - 배추가격 :  [315.64944]
# # 2000 손실비용 :  3220193.0
# - 배추가격 :  [566.53516]
# # 2500 손실비용 :  3023275.2
# - 배추가격 :  [789.4281]
# # 3000 손실비용 :  2867783.0
# - 배추가격 :  [987.508]
# # 3500 손실비용 :  2744871.0
# - 배추가격 :  [1163.5729]
# # 4000 손실비용 :  2647640.2
# - 배추가격 :  [1320.0984]
# # 4500 손실비용 :  2570682.8
# - 배추가격 :  [1459.2731]
# # 5000 손실비용 :  2509741.8
# - 배추가격 :  [1583.0344]
# # 5500 손실비용 :  2461465.0
# - 배추가격 :  [1693.099]
# # 6000 손실비용 :  2423204.2
# - 배추가격 :  [1790.992]
# # 6500 손실비용 :  2392866.2
# - 배추가격 :  [1878.0625]
# # 7000 손실비용 :  2368797.2
# - 배추가격 :  [1955.5112]
# # 7500 손실비용 :  2349691.2
# - 배추가격 :  [2024.4044]
# # 8000 손실비용 :  2334509.0
# - 배추가격 :  [2085.6895]
# # 8500 손실비용 :  2322433.8
# - 배추가격 :  [2140.2073]
# # 9000 손실비용 :  2312818.0
# - 배추가격 :  [2188.7073]
# # 9500 손실비용 :  2305148.2
# - 배추가격 :  [2231.8547]
# # 10000 손실비용 :  2299018.0
# - 배추가격 :  [2270.2402]
# # 10500 손실비용 :  2294107.0
# - 배추가격 :  [2304.3906]
# # 11000 손실비용 :  2290160.5
# - 배추가격 :  [2334.7734]
# # 11500 손실비용 :  2286977.5
# - 배추가격 :  [2361.8044]
# # 12000 손실비용 :  2284398.2
# - 배추가격 :  [2385.855]
# # 12500 손실비용 :  2282298.0
# - 배추가격 :  [2407.2534]
# # 13000 손실비용 :  2280576.5
# - 배추가격 :  [2426.2925]
# # 13500 손실비용 :  2279154.0
# - 배추가격 :  [2443.2322]
# # 14000 손실비용 :  2277969.2
# - 배추가격 :  [2458.3054]
# # 14500 손실비용 :  2276972.5
# - 배추가격 :  [2471.718]
# # 15000 손실비용 :  2276123.8
# - 배추가격 :  [2483.6514]
# # 15500 손실비용 :  2275392.2
# - 배추가격 :  [2494.2717]
# # 16000 손실비용 :  2274754.0
# - 배추가격 :  [2503.7224]
# # 16500 손실비용 :  2274191.2
# - 배추가격 :  [2512.1328]
# # 17000 손실비용 :  2273685.8
# - 배추가격 :  [2519.618]
# # 17500 손실비용 :  2273225.8
# - 배추가격 :  [2526.2788]
# # 18000 손실비용 :  2272803.8
# - 배추가격 :  [2532.2068]
# # 18500 손실비용 :  2272410.0
# - 배추가격 :  [2537.4836]
# # 19000 손실비용 :  2272039.0
# - 배추가격 :  [2542.1814]
# # 19500 손실비용 :  2271687.0
# - 배추가격 :  [2546.3618]
# # 20000 손실비용 :  2271350.8
# - 배추가격 :  [2550.0845]
# # 20500 손실비용 :  2271024.2
# - 배추가격 :  [2553.3992]
# # 21000 손실비용 :  2270706.8
# - 배추가격 :  [2556.35]
# # 21500 손실비용 :  2270397.5
# - 배추가격 :  [2558.9773]
# # 22000 손실비용 :  2270093.2
# - 배추가격 :  [2561.318]
# # 22500 손실비용 :  2269793.5
# - 배추가격 :  [2563.401]
# # 23000 손실비용 :  2269500.0
# - 배추가격 :  [2565.2612]
# # 23500 손실비용 :  2269206.5
# - 배추가격 :  [2566.9128]
# # 24000 손실비용 :  2268916.2
# - 배추가격 :  [2568.3862]
# # 24500 손실비용 :  2268629.8
# - 배추가격 :  [2569.7]
# # 25000 손실비용 :  2268342.0
# - 배추가격 :  [2570.871]
# # 25500 손실비용 :  2268057.0
# - 배추가격 :  [2571.9155]
# # 26000 손실비용 :  2267772.2
# - 배추가격 :  [2572.8506]
# # 26500 손실비용 :  2267490.0
# - 배추가격 :  [2573.687]
# # 27000 손실비용 :  2267207.8
# - 배추가격 :  [2574.423]
# # 27500 손실비용 :  2266924.2
# - 배추가격 :  [2575.0762]
# # 28000 손실비용 :  2266644.2
# - 배추가격 :  [2575.6814]
# # 28500 손실비용 :  2266364.2
# - 배추가격 :  [2576.2107]
# # 29000 손실비용 :  2266083.0
# - 배추가격 :  [2576.6963]
# # 29500 손실비용 :  2265803.5
# - 배추가격 :  [2577.1238]
# # 30000 손실비용 :  2265522.2
# - 배추가격 :  [2577.4954]
# # 30500 손실비용 :  2265244.0
# - 배추가격 :  [2577.8352]
# # 31000 손실비용 :  2264965.0
# - 배추가격 :  [2578.1626]
# # 31500 손실비용 :  2264685.2
# - 배추가격 :  [2578.41]
# # 32000 손실비용 :  2264407.5
# - 배추가격 :  [2578.652]
# # 32500 손실비용 :  2264129.0
# - 배추가격 :  [2578.894]
# # 33000 손실비용 :  2263849.2
# - 배추가격 :  [2579.128]
# # 33500 손실비용 :  2263573.2
# - 배추가격 :  [2579.3174]
# # 34000 손실비용 :  2263294.0
# - 배추가격 :  [2579.4492]
# # 34500 손실비용 :  2263017.0
# - 배추가격 :  [2579.5781]
# # 35000 손실비용 :  2262740.0
# - 배추가격 :  [2579.7063]
# # 35500 손실비용 :  2262463.8
# - 배추가격 :  [2579.8342]
# # 36000 손실비용 :  2262186.5
# - 배추가격 :  [2579.962]
# # 36500 손실비용 :  2261909.8
# - 배추가격 :  [2580.0898]
# # 37000 손실비용 :  2261633.8
# - 배추가격 :  [2580.2175]
# # 37500 손실비용 :  2261358.0
# - 배추가격 :  [2580.3438]
# # 38000 손실비용 :  2261081.8
# - 배추가격 :  [2580.465]
# # 38500 손실비용 :  2260804.8
# - 배추가격 :  [2580.519]
# # 39000 손실비용 :  2260528.2
# - 배추가격 :  [2580.5564]
# # 39500 손실비용 :  2260253.0
# - 배추가격 :  [2580.5938]
# # 40000 손실비용 :  2259978.8
# - 배추가격 :  [2580.6304]
# # 40500 손실비용 :  2259703.8
# - 배추가격 :  [2580.6638]
# # 41000 손실비용 :  2259429.2
# - 배추가격 :  [2580.697]
# # 41500 손실비용 :  2259154.5
# - 배추가격 :  [2580.7292]
# # 42000 손실비용 :  2258879.8
# - 배추가격 :  [2580.7625]
# # 42500 손실비용 :  2258606.8
# - 배추가격 :  [2580.7957]
# # 43000 손실비용 :  2258331.8
# - 배추가격 :  [2580.8289]
# # 43500 손실비용 :  2258058.5
# - 배추가격 :  [2580.8618]
# # 44000 손실비용 :  2257784.5
# - 배추가격 :  [2580.8955]
# # 44500 손실비용 :  2257511.2
# - 배추가격 :  [2580.929]
# # 45000 손실비용 :  2257237.2
# - 배추가격 :  [2580.9624]
# # 45500 손실비용 :  2256964.2
# - 배추가격 :  [2580.9958]
# # 46000 손실비용 :  2256690.5
# - 배추가격 :  [2581.0293]
# # 46500 손실비용 :  2256418.0
# - 배추가격 :  [2581.063]
# # 47000 손실비용 :  2256144.8
# - 배추가격 :  [2581.0972]
# # 47500 손실비용 :  2255873.2
# - 배추가격 :  [2581.1296]
# # 48000 손실비용 :  2255602.8
# - 배추가격 :  [2581.1636]
# # 48500 손실비용 :  2255330.5
# - 배추가격 :  [2581.198]
# # 49000 손실비용 :  2255059.0
# - 배추가격 :  [2581.2354]
# # 49500 손실비용 :  2254788.0
# - 배추가격 :  [2581.2732]
# # 50000 손실비용 :  2254518.0
# - 배추가격 :  [2581.313]
# # 50500 손실비용 :  2254246.5
# - 배추가격 :  [2581.3552]
# # 51000 손실비용 :  2253976.0
# - 배추가격 :  [2581.3975]
# # 51500 손실비용 :  2253705.8
# - 배추가격 :  [2581.4412]
# # 52000 손실비용 :  2253435.2
# - 배추가격 :  [2581.487]
# # 52500 손실비용 :  2253164.8
# - 배추가격 :  [2581.533]
# # 53000 손실비용 :  2252894.5
# - 배추가격 :  [2581.5793]
# # 53500 손실비용 :  2252624.0
# - 배추가격 :  [2581.6262]
# # 54000 손실비용 :  2252354.8
# - 배추가격 :  [2581.676]
# # 54500 손실비용 :  2252084.8
# - 배추가격 :  [2581.7244]
# # 55000 손실비용 :  2251816.2
# - 배추가격 :  [2581.7686]
# # 55500 손실비용 :  2251548.5
# - 배추가격 :  [2581.813]
# # 56000 손실비용 :  2251280.0
# - 배추가격 :  [2581.86]
# # 56500 손실비용 :  2251011.8
# - 배추가격 :  [2581.9084]
# # 57000 손실비용 :  2250743.2
# - 배추가격 :  [2581.9565]
# # 57500 손실비용 :  2250475.5
# - 배추가격 :  [2582.005]
# # 58000 손실비용 :  2250207.5
# - 배추가격 :  [2582.0522]
# # 58500 손실비용 :  2249941.0
# - 배추가격 :  [2582.095]
# # 59000 손실비용 :  2249675.0
# - 배추가격 :  [2582.1372]
# # 59500 손실비용 :  2249407.8
# - 배추가격 :  [2582.1873]
# # 60000 손실비용 :  2249142.0
# - 배추가격 :  [2582.2375]
# # 60500 손실비용 :  2248875.2
# - 배추가격 :  [2582.2878]
# # 61000 손실비용 :  2248610.0
# - 배추가격 :  [2582.3384]
# # 61500 손실비용 :  2248343.0
# - 배추가격 :  [2582.3857]
# # 62000 손실비용 :  2248077.8
# - 배추가격 :  [2582.4192]
# # 62500 손실비용 :  2247811.8
# - 배추가격 :  [2582.4526]
# # 63000 손실비용 :  2247546.2
# - 배추가격 :  [2582.486]
# # 63500 손실비용 :  2247281.0
# - 배추가격 :  [2582.5198]
# # 64000 손실비용 :  2247014.5
# - 배추가격 :  [2582.5532]
# # 64500 손실비용 :  2246750.2
# - 배추가격 :  [2582.5867]
# # 65000 손실비용 :  2246484.8
# - 배추가격 :  [2582.62]
# # 65500 손실비용 :  2246219.8
# - 배추가격 :  [2582.654]
# # 66000 손실비용 :  2245954.5
# - 배추가격 :  [2582.6877]
# # 66500 손실비용 :  2245690.2
# - 배추가격 :  [2582.7217]
# # 67000 손실비용 :  2245425.5
# - 배추가격 :  [2582.7554]
# # 67500 손실비용 :  2245160.8
# - 배추가격 :  [2582.7898]
# # 68000 손실비용 :  2244896.2
# - 배추가격 :  [2582.8235]
# # 68500 손실비용 :  2244632.0
# - 배추가격 :  [2582.8594]
# # 69000 손실비용 :  2244367.2
# - 배추가격 :  [2582.9072]
# # 69500 손실비용 :  2244103.5
# - 배추가격 :  [2582.9583]
# # 70000 손실비용 :  2243839.8
# - 배추가격 :  [2583.0066]
# # 70500 손실비용 :  2243575.0
# - 배추가격 :  [2583.052]
# # 71000 손실비용 :  2243312.0
# - 배추가격 :  [2583.0974]
# # 71500 손실비용 :  2243047.8
# - 배추가격 :  [2583.14]
# # 72000 손실비용 :  2242784.5
# - 배추가격 :  [2583.18]
# # 72500 손실비용 :  2242521.0
# - 배추가격 :  [2583.2202]
# # 73000 손실비용 :  2242259.2
# - 배추가격 :  [2583.2563]
# # 73500 손실비용 :  2241997.2
# - 배추가격 :  [2583.284]
# # 74000 손실비용 :  2241737.0
# - 배추가격 :  [2583.3113]
# # 74500 손실비용 :  2241476.0
# - 배추가격 :  [2583.3389]
# # 75000 손실비용 :  2241215.2
# - 배추가격 :  [2583.366]
# # 75500 손실비용 :  2240955.2
# - 배추가격 :  [2583.3896]
# # 76000 손실비용 :  2240694.5
# - 배추가격 :  [2583.4116]
# # 76500 손실비용 :  2240434.5
# - 배추가격 :  [2583.434]
# # 77000 손실비용 :  2240173.5
# - 배추가격 :  [2583.4558]
# # 77500 손실비용 :  2239914.0
# - 배추가격 :  [2583.478]
# # 78000 손실비용 :  2239653.0
# - 배추가격 :  [2583.499]
# # 78500 손실비용 :  2239394.5
# - 배추가격 :  [2583.516]
# # 79000 손실비용 :  2239134.5
# - 배추가격 :  [2583.5325]
# # 79500 손실비용 :  2238874.5
# - 배추가격 :  [2583.5493]
# # 80000 손실비용 :  2238616.0
# - 배추가격 :  [2583.5662]
# # 80500 손실비용 :  2238355.2
# - 배추가격 :  [2583.583]
# # 81000 손실비용 :  2238096.5
# - 배추가격 :  [2583.5996]
# # 81500 손실비용 :  2237836.8
# - 배추가격 :  [2583.6157]
# # 82000 손실비용 :  2237578.5
# - 배추가격 :  [2583.6274]
# # 82500 손실비용 :  2237319.8
# - 배추가격 :  [2583.639]
# # 83000 손실비용 :  2237060.2
# - 배추가격 :  [2583.6501]
# # 83500 손실비용 :  2236802.2
# - 배추가격 :  [2583.6616]
# # 84000 손실비용 :  2236543.5
# - 배추가격 :  [2583.673]
# # 84500 손실비용 :  2236286.0
# - 배추가격 :  [2583.6848]
# # 85000 손실비용 :  2236026.2
# - 배추가격 :  [2583.696]
# # 85500 손실비용 :  2235767.5
# - 배추가격 :  [2583.7075]
# # 86000 손실비용 :  2235510.0
# - 배추가격 :  [2583.719]
# # 86500 손실비용 :  2235251.5
# - 배추가격 :  [2583.729]
# # 87000 손실비용 :  2234993.5
# - 배추가격 :  [2583.7349]
# # 87500 손실비용 :  2234735.5
# - 배추가격 :  [2583.7412]
# # 88000 손실비용 :  2234477.8
# - 배추가격 :  [2583.7554]
# # 88500 손실비용 :  2234221.2
# - 배추가격 :  [2583.7896]
# # 89000 손실비용 :  2233963.2
# - 배추가격 :  [2583.8237]
# # 89500 손실비용 :  2233705.5
# - 배추가격 :  [2583.8582]
# # 90000 손실비용 :  2233448.8
# - 배추가격 :  [2583.892]
# # 90500 손실비용 :  2233193.5
# - 배추가격 :  [2583.926]
# # 91000 손실비용 :  2232939.0
# - 배추가격 :  [2583.9595]
# # 91500 손실비용 :  2232683.2
# - 배추가격 :  [2583.9932]
# # 92000 손실비용 :  2232429.8
# - 배추가격 :  [2584.0266]
# # 92500 손실비용 :  2232175.5
# - 배추가격 :  [2584.061]
# # 93000 손실비용 :  2231921.2
# - 배추가격 :  [2584.0945]
# # 93500 손실비용 :  2231667.2
# - 배추가격 :  [2584.1284]
# # 94000 손실비용 :  2231412.8
# - 배추가격 :  [2584.1626]
# # 94500 손실비용 :  2231159.8
# - 배추가격 :  [2584.1968]
# # 95000 손실비용 :  2230905.8
# - 배추가격 :  [2584.231]
# # 95500 손실비용 :  2230652.0
# - 배추가격 :  [2584.265]
# # 96000 손실비용 :  2230398.8
# - 배추가격 :  [2584.299]
# # 96500 손실비용 :  2230145.2
# - 배추가격 :  [2584.3328]
# # 97000 손실비용 :  2229891.8
# - 배추가격 :  [2584.3674]
# # 97500 손실비용 :  2229639.2
# - 배추가격 :  [2584.4019]
# # 98000 손실비용 :  2229386.2
# - 배추가격 :  [2584.4365]
# # 98500 손실비용 :  2229134.0
# - 배추가격 :  [2584.471]
# # 99000 손실비용 :  2228881.0
# - 배추가격 :  [2584.5051]
# # 99500 손실비용 :  2228628.8
# - 배추가격 :  [2584.54]
# # 100000 손실비용 :  2228375.5
# - 배추가격 :  [2584.5742]

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./data/saved.cpkt")
print('Done : ','학습된 모델을 저장하였습니다.')
# Out:
# Done 학습된 모델을 저장하였습니다.
